# %%
from scripts.regsetup import description

financial_keywords = [
    "market", "stock", "bond", "exchange", "index", "investor", "rate", "forecast", "futures", "option", "IPO", "economy", "GDP", "crisis", "debt", "credit", "liquidity", "capital", "return", "hedge", "diversification", "finance", "insurance", "tax", "budget", "reporting", "public finance", "cash flow", "consumer credit", "patent", "currency control", "balance", "debt servicing", "bankruptcy", "Elon Musk", "Warren Buffett", "Jamie Dimon", "Christine Lagarde", "Jerome Powell", "Janet Yellen", "Larry Fink", "Cathie Wood", "Bill Gates", "Jeff Bezos", "Federal Reserve", "European Central Bank", "Bank of England", "Bank of Japan", "Wall Street", "New York", "London", "Tokyo", "United States", "China", "Japan", "Germany", "United Kingdom", "France", "Canada", "Australia", "Goldman Sachs", "JPMorgan Chase", "BlackRock", "Vanguard", "Morgan Stanley", "Citibank", "Bank of America", "Wells Fargo", "Apple", "Microsoft", "Amazon", "Alphabet", "Meta", "Tesla", "Berkshire Hathaway", "Alibaba", "Samsung", "Nestle", "Bitcoin", "Ethereum", "Ripple", "Litecoin", "Binance Coin", "Cardano", "Tether", "Polkadot", "Solana", "Dogecoin", "Chainlink", "USD Coin", "Uniswap", "Avalanche"
]

# %%
len(financial_keywords)
# Out:
# 92

# %%
important_countries = [
    ("us", "en"),  # United States
    ("gb", "en"),  # United Kingdom
    ("de", "de"),  # Germany
    ("fr", "fr"),  # France
    ("jp", None),  # Japan
    ("cn", "zh"),  # China
    ("ch", "de"),  # Switzerland
    ("ca", "en"),  # Canada
    ("au", "en"),  # Australia
    ("sg", "en"),  # Singapore
    ("hk", "zh"),  # Hong Kong
    ("kr", None),  # South Korea
    ("in", "en"),  # India
    ("br", "pt"),  # Brazil
    ("ru", "ru"),  # Russia
    ("nl", "nl"),  # Netherlands
    ("it", "it"),  # Italy
    ("es", "es"),  # Spain
    ("se", "sv"),  # Sweden
    ("no", "no")   # Norway
]

# %%
from newsapi import NewsApiClient
import pandas as pd
from tqdm.notebook import tqdm

newsapi = NewsApiClient(api_key='530ccc02225549578643df37fc6e626d')

data_top_results = pd.DataFrame()

for i in tqdm(important_countries):
    top_headlines = newsapi.get_top_headlines(category='business')
    data_remaining = pd.DataFrame(top_headlines['articles'])
    print(data_remaining.shape)
    data_top_results = pd.concat([data_top_results, data_remaining], ignore_index=True)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)
# (19, 8)

# %%
data_top_results
# Out:
#                                                 source  \
# 0                  {'id': None, 'name': 'MarketWatch'}
# 1    {'id': 'the-washington-post', 'name': 'The Was...
# 2           {'id': 'techcrunch', 'name': 'TechCrunch'}
# 3                     {'id': 'axios', 'name': 'Axios'}
# 4                 {'id': None, 'name': 'Tipranks.com'}
# ..                                                 ...
# 945           {'id': None, 'name': 'Realtor.com News'}
# 946           {'id': 'bloomberg', 'name': 'Bloomberg'}
# 947               {'id': None, 'name': 'ScienceAlert'}
# 948             {'id': None, 'name': 'Travel+Leisure'}
# 949                   {'id': 'axios', 'name': 'Axios'}
#
#                                                 author  \
# 0    Christine Idzelis, Steve Gelsi, Joseph Adinolf...
# 1                                       Bethany McLean
# 2                                          Sarah Perez
# 3                          Courtenay Brown, Neil Irwin
# ...

# %%
data_top_results['url'].values
# Out:
# array(['https://www.marketwatch.com/livecoverage/stock-market-today-dow-and-s-p-500-line-up-for-more-records-as-shutdown-cancels-jobs-data',
#        'https://www.washingtonpost.com/business/2025/10/03/ai-will-trigger-financial-calamity-itll-also-remake-world/',
#        'https://techcrunch.com/2025/10/03/openais-sora-soars-to-no-1-on-the-u-s-app-store/',
#        'https://www.axios.com/2025/10/03/government-shutdown-jobs-report-september-adp',
#        'https://www.tipranks.com/news/ai-is-in-an-industrial-bubble-says-amazon-amzn-founder-jeff-bezos',
#        'https://www.barrons.com/articles/quantum-computing-stock-price-buy-3b216737',
#        'https://news.google.com/rss/articles/CBMihgFBVV95cUxPeU1aSXV4OXhScUZ1Zlk0UUpBUHlaTHQtOUNISklfbW9xS21ZVVpYcjJhM05jMTZ3WEZqUTJDWU1wVmxHMHBzVDYxcUpjcnJEdkRCWm1BaURPSnJma2VJVFdvbl9Qc1kwQkg2ZC1iN2JDakFOYjlVejU0SDZqQjFpajhILTBZdw?oc=5',
#        'https://finance.yahoo.com/news/silicon-valley-leader-navigated-internets-123623069.html',
# ...

# %%
trusted_links = ["bbc-news", "bloomberg", "reuters", "thewallstreetjournal", "financialtimes", "cnbc", "forbes", "theeconomist", "newyorktimes", "nasdaq", "marketwatch", "investing", "bbcnewsbusiness", "cnnbusiness", "theguardianbusiness", "washingtonpostbusiness", "aljazeeraeconomy", "france24business", "timesofindiabusiness", "sydneymorningheraldbusiness", "handelsblatt", "lemondeéconomie", "lesechos", "elpaiseconomía", "decrypt", "the block", "coingape", "coindesk", "cointelegraph", "decrypt", "ambcrypto", "bitcoinist", "beincrypto", "coincodex", "thedailyhodl", "theblock", "coingape", "cryptobriefing", "cryptopotato", "newsbtc", "u.today"]

# %%
data_top_results['url'].nunique()
# Out:
# 19

# %%
def filter_trusted_sources(df, trusted_links_str):
    def url_contains_trusted(url):
        if not isinstance(url, str):
            return False
        url_lower = url.lower()
        return any(site.lower() in url_lower for site in trusted_links)

    filtered_df = df[df['url'].apply(url_contains_trusted)].copy()
    return filtered_df

# %%
filtered_data = filter_trusted_sources(data_top_results, trusted_links)

# %%
filtered_data
# Out:
#                                       source  \
# 0        {'id': None, 'name': 'MarketWatch'}
# 9            {'id': None, 'name': 'Decrypt'}
# 15  {'id': 'bloomberg', 'name': 'Bloomberg'}
#
#                                                author  \
# 0   Christine Idzelis, Steve Gelsi, Joseph Adinolf...
# 9                                         Stacy Jones
# 15                                     Olivia Fishlow
#
#                                                 title  \
# 0   Stock Market Today: Dow up 400 points; S&P 500...
# 9   Bitcoin Could Reach $135,000 Soon: Standard Ch...
# 15  First Brands’ Fallout Exposes Risks of Lending...
#
#                                           description  \
# 0   The U.S. stock market was trading mixed Friday...
# 9   The bank's Global Head of Digital Assets Resea...
# 15  Since First Brands Group filed for bankruptcy ...
#
#                                                   url  \
# 0   https://www.marketwatch.com/livecoverage/stock...
# ...

# %%
filtered_data.shape
# Out:
# (3, 8)
